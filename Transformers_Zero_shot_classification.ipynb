# %% [markdown]
# <a href="https://colab.research.google.com/github/dharini-projects/NLP_Applications_with_Transformers/blob/main/Transformers_Zero_shot_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 182 kB 54.0 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 52.2 MB/s
# ...

# %%
from transformers import pipeline
zero_shot_classifier = pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
input_sentence = "I am hungry and angry. I think an ice cream will make me feel good"
labels = ['food', 'travel','entertainment','sad','happy','neutral']

# %%
results = zero_shot_classifier(input_sentence, labels)

# %%
print(results)
# Out:
# {'sequence': 'I am hungry and angry. I think an ice cream will make me feel good', 'labels': ['food', 'sad', 'entertainment', 'travel', 'neutral', 'happy'], 'scores': [0.8720405101776123, 0.07575708627700806, 0.023996146395802498, 0.010163746774196625, 0.009797507897019386, 0.00824508722871542]}

# %%
import pandas as pd
df_result = pd.DataFrame(results)
print(df_result)
# Out:
#                                             sequence         labels    scores
# 0  I am hungry and angry. I think an ice cream wi...           food  0.872041
# 1  I am hungry and angry. I think an ice cream wi...            sad  0.075757
# 2  I am hungry and angry. I think an ice cream wi...  entertainment  0.023996
# 3  I am hungry and angry. I think an ice cream wi...         travel  0.010164
# 4  I am hungry and angry. I think an ice cream wi...        neutral  0.009798
# 5  I am hungry and angry. I think an ice cream wi...          happy  0.008245

# %%
print(df_result.loc[:, ['labels','scores']])
# Out:
#           labels    scores
# 0           food  0.872041
# 1            sad  0.075757
# 2  entertainment  0.023996
# 3         travel  0.010164
# 4        neutral  0.009798
# 5          happy  0.008245
