# %% [markdown]
# <a href="https://colab.research.google.com/github/dharini-projects/NLP_Applications_with_Transformers/blob/main/Transformers_Fill_Mask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 4.4 MB/s
# ...
#      |████████████████████████████████| 182 kB 32.2 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 35.0 MB/s
# ...

# %%
from transformers import pipeline

# %%
fill_mask_clf = pipeline("fill-mask")
# Out:
# No model was supplied, defaulted to distilroberta-base and revision ec58a5b (https://huggingface.co/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
fill_mask_clf("Education of <mask> uplifts the society")
# Out:
# [{'score': 0.027368566021323204,
#   'token': 408,
#   'token_str': ' children',
#   'sequence': 'Education of children uplifts the society'},
#  {'score': 0.022516481578350067,
#   'token': 7503,
#   'token_str': ' Islam',
#   'sequence': 'Education of Islam uplifts the society'},
#  {'score': 0.022105561569333076,
#   'token': 2866,
#   'token_str': ' science',
#   'sequence': 'Education of science uplifts the society'},
#  {'score': 0.021794229745864868,
#   'token': 390,
#   'token_str': ' women',
#   'sequence': 'Education of women uplifts the society'},
#  {'score': 0.0205514095723629,
#   'token': 5772,
#   'token_str': ' Jesus',
#   'sequence': 'Education of Jesus uplifts the society'}]

# %%
fill_mask_clf("women are <mask> in the world")
# Out:
# [{'score': 0.08681367337703705,
#   'token': 32881,
#   'token_str': ' oppressed',
#   'sequence': 'women are oppressed in the world'},
#  {'score': 0.08290907740592957,
#   'token': 6128,
#   'token_str': ' everywhere',
#   'sequence': 'women are everywhere in the world'},
#  {'score': 0.04406027868390083,
#   'token': 25190,
#   'token_str': ' marginalized',
#   'sequence': 'women are marginalized in the world'},
#  {'score': 0.02857658453285694,
#   'token': 8180,
#   'token_str': ' dying',
#   'sequence': 'women are dying in the world'},
#  {'score': 0.02574598230421543,
#   'token': 917,
#   'token_str': ' leaders',
#   'sequence': 'women are leaders in the world'}]

# %%
fill_mask_clf("artificial intelligence is going to be <mask> in the future")
# Out:
# [{'score': 0.061495572328567505,
#   'token': 30208,
#   'token_str': ' commonplace',
#   'sequence': 'artificial intelligence is going to be commonplace in the future'},
#  {'score': 0.05322642996907234,
#   'token': 25107,
#   'token_str': ' ubiquitous',
#   'sequence': 'artificial intelligence is going to be ubiquitous in the future'},
#  {'score': 0.0344822071492672,
#   'token': 5616,
#   'token_str': ' useful',
#   'sequence': 'artificial intelligence is going to be useful in the future'},
#  {'score': 0.033160075545310974,
#   'token': 6128,
#   'token_str': ' everywhere',
#   'sequence': 'artificial intelligence is going to be everywhere in the future'},
#  {'score': 0.025654001161456108,
#   'token': 956,
#   'token_str': ' needed',
#   'sequence': 'artificial intelligence is going to be needed in the future'}]
