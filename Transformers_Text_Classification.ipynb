# %% [markdown]
# <a href="https://colab.research.google.com/github/dharini-projects/NLP_with_Transformers/blob/main/Transformers_Text_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 25.2 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 61.3 MB/s
# ...
#      |████████████████████████████████| 182 kB 69.1 MB/s
# ...

# %%
from transformers import pipeline

# %% [markdown]
# ## **TEXT CLASSIFICATION**

# %%
text_classifier = pipeline("text-classification")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
clf_result = text_classifier("Oh God!!!! Its so horrible to hear about the news of aircraft")

# %%
clf_result
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9992474317550659}]

# %%
clf_result = text_classifier("Oh God!!!! So relieved to hear about the arcraft")

# %%
clf_result
# Out:
# [{'label': 'POSITIVE', 'score': 0.9974811673164368}]
